# %%
import tensorflow as tf
import datetime
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from collections import Counter
from random import shuffle
from tqdm import tqdm
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from tensorflow.python.framework import graph_util
import seaborn as sns
# %matplotlib inline

# %%
print(f'OpenCV version: {cv2.__version__}')
print(f'Tensorflow version: {tf.__version__}')
# Out:
# OpenCV version: 4.1.0
# Tensorflow version: 1.14.0

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ### Useful Parameters

# %%
DATE = datetime.datetime.now().strftime('%d-%b-%Y')
TRAIN_DIR = 'data/train'
TEST_DIR = 'data/test'
IMG_SIZE = 50
LR = 1e-3
MODEL_PATH = f'models/{DATE}'
MODEL_NAME = 'ImageClassifier-{}.model'.format('6-conv-layer')
NUM_CLASSES = len(next(os.walk(TRAIN_DIR))[1])
DATE
# Out:
# '23-Sep-2019'

# %% [markdown]
# ### Walkthrough of Subfolders in Train Directory:

# %%
# Only the root
ROOTS = next(os.walk(TRAIN_DIR))[0]
print(f"Roots = {ROOTS}")
# Out:
# Roots = data/train

# %%
# Only the directories
DIRS = next(os.walk(TRAIN_DIR))[1]
print(f"Dirs = {DIRS}")
# Out:
# Dirs = ['Allie Haze', 'Ariel X', 'Ariella Ferrera', 'Mellanie Monroe', 'Samantha Ryan', 'Tanya Tate']

# %%
# Only the files
for root, dirs, files in os.walk(TRAIN_DIR):
    for name in files:
        print(name.split('.')[0].split('(')[0]) # filters the file name by file extension and the copy_number
# Out:
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Allie Haze
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariel X
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Ariella Ferrera
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Mellanie Monroe
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Samantha Ryan
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate
# Tanya Tate

# %% [markdown]
# ### Generation of Image classes

# %%
def get_class_labels():
    labels = []
    for root, dirs, files in os.walk(TRAIN_DIR):
        path = root.split(os.sep)
        for subfolder in dirs:
            name = subfolder.split()
            class_label = "".join([letter[0] for letter in name])
            labels.append(class_label)
    return labels

# %% [markdown]
# ### One-Hot Encoding

# %%
LABELS = next(os.walk(TRAIN_DIR))[1] # all the class labels (pornstar names) to be used
LABELS = np.reshape(LABELS, (-1, 1)) # reshapes array from 1D to 2D array
mlb = MultiLabelBinarizer()
encoded_labels = np.array(mlb.fit_transform(LABELS))

# %%
dict(zip(LABELS.flatten(), encoded_labels))
# Out:
# {'Allie Haze': array([1, 0, 0, 0, 0, 0]),
#  'Ariel X': array([0, 1, 0, 0, 0, 0]),
#  'Ariella Ferrera': array([0, 0, 1, 0, 0, 0]),
#  'Mellanie Monroe': array([0, 0, 0, 1, 0, 0]),
#  'Samantha Ryan': array([0, 0, 0, 0, 1, 0]),
#  'Tanya Tate': array([0, 0, 0, 0, 0, 1])}

# %%
"""
Labelled training data
"""
def create_train_data():
    training_data = []
    # iterate over each image-class (subfolder) in training directory
    for folder in tqdm(os.listdir(TRAIN_DIR)):
        full_path = f'{TRAIN_DIR}/{folder}'
        # iterate over each image in each subfolder
        for img in os.listdir(full_path):
            img_name = img.split('.')[0].split('(')[0]  # extracts the image class from file name
            img_name = img_name.strip() # removes any leading and trailing whitespaces from the img name
            label = mlb.transform([[img_name]]) # encodes the label of the image using MultiLabelBinarizer
            label = label.flatten()  # converts encoded label from 2D to 1D array
            # print(f'Image: {img} - Encoding:{label}')
            path = os.path.join(full_path, img)  # full path of the image
            img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
            training_data.append([np.array(img), np.array(label)])
    shuffle(training_data)
    np.save('train_data.npy', training_data)
    return training_data

# %%
"""
Unlabelled test data
"""
def process_test_data():
    testing_data = []
    for img in tqdm(os.listdir(TEST_DIR)):
        path = os.path.join(TEST_DIR, img)
        img_num = img.split('.')[0]
        img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
        testing_data.append([np.array(img), img_num])
    np.save('test_data.npy', testing_data)
    return testing_data

# %%
train_data = create_train_data()
# test_data = process_test_data()
# if train/test data already exists
# train_data = np.load('train_data.npy', allow_pickle=True)
test_data = np.load('test_data.npy', allow_pickle=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  3.84it/s]

# %% [markdown]
# # BUILDING THE MODEL

# %% [markdown]
# ### Implementation of Convoluted Neural Network

# %%
import tflearn
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.estimator import regression

def create_cnn_model():
    tf.reset_default_graph()

    # INPUT_LAYER
    convnet = input_data(shape=[None, IMG_SIZE, IMG_SIZE, 1], name='input')

    # HIDDEN_LAYER_1
    convnet = conv_2d(convnet, 32, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # HIDDEN_LAYER_2
    convnet = conv_2d(convnet, 64, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # HIDDEN_LAYER_3
    convnet = conv_2d(convnet, 128, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # HIDDEN_LAYER_4
    convnet = conv_2d(convnet, 32, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # HIDDEN_LAYER_5
    convnet = conv_2d(convnet, 64, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # HIDDEN_LAYER_6
    convnet = conv_2d(convnet, 128, 6, activation='relu')
    convnet = max_pool_2d(convnet, 6)

    # FULLY_CONNECTED_LAYER
    convnet = fully_connected(convnet, 1024, activation='relu')
    convnet = dropout(convnet, 0.8)

    # OUTPUT LAYER
    convnet = fully_connected(convnet, NUM_CLASSES, activation='softmax')
    convnet = regression(convnet, optimizer='adam', learning_rate=LR, loss='categorical_crossentropy', name='targets')

    model = tflearn.DNN(convnet, tensorboard_dir='log')
    return convnet, model
# Out:
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# WARNING: Logging before flag parsing goes to stderr.
# W0923 10:37:26.429922 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\helpers\summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0923 10:37:26.435907 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\helpers\trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0923 10:37:26.469816 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0923 10:37:26.488765 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0923 10:37:26.500735 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W0923 10:37:26.502728 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
CONVNET, MODEL = create_cnn_model()
if os.path.exists(f'{MODEL_PATH}/{MODEL_NAME}.meta'):
    MODEL.load(f'{MODEL_PATH}/{MODEL_NAME}')
    print('model loaded!')
# Out:
# W0923 10:37:26.516690 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\layers\core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0923 10:37:26.520680 18044 deprecation.py:506] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\initializations.py:119: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 10:37:26.524670 18044 deprecation.py:323] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\deprecation.py:507: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# W0923 10:37:26.550600 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\layers\conv.py:552: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0923 10:37:26.642356 18044 deprecation.py:506] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\initializations.py:174: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 10:37:26.684243 18044 deprecation.py:506] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\layers\core.py:239: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0923 10:37:26.712168 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\optimizers.py:238: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0923 10:37:26.719149 18044 deprecation.py:506] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\objectives.py:66: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0923 10:37:26.782980 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\summaries.py:46: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0923 10:37:26.836834 18044 deprecation.py:323] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0923 10:37:27.211831 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tflearn\helpers\trainer.py:134: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0923 10:37:27.700524 18044 deprecation.py:323] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# model loaded!

# %% [markdown]
# # TRAINING THE NETWORK

# %%
train = train_data[:-100] # sample train data
test = train_data[-100:]

# %% [markdown]
# ### Frequency distribution of classes being used in "test data"

# %%
enc = []
for img in test:
    enc.append(img[1])
    
enc = np.array(enc)
test_labels = mlb.inverse_transform(enc)
c = Counter(test_labels)
c
# Out:
# Counter({('Ariella Ferrera',): 21,
#          ('Mellanie Monroe',): 17,
#          ('Samantha Ryan',): 9,
#          ('Ariel X',): 16,
#          ('Tanya Tate',): 22,
#          ('Allie Haze',): 15})

# %%
X = np.array([i[0] for i in train]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
Y = [i[1] for i in train]

test_X = np.array([i[0] for i in test]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
test_Y = [i[1] for i in test]

# %%
MODEL.fit({'input': X}, {'targets': Y}, n_epoch=100, validation_set=({'input': test_X}, {'targets': test_Y}), 
    snapshot_step=500, show_metric=True, run_id=MODEL_NAME)
# Out:
# Training Step: 2099  | total loss: 0.78883 | time: 1.027s
# | Adam | epoch: 100 | loss: 0.78883 - acc: 0.9140 -- iter: 384/423
# Training Step: 2100  | total loss: 0.71593 | time: 2.238s
# | Adam | epoch: 100 | loss: 0.71593 - acc: 0.9226 | val_loss: 0.12065 - val_acc: 0.9800 -- iter: 423/423
# --

# %%
with CONVNET.graph.as_default():
    del tf.get_collection_ref(tf.GraphKeys.TRAIN_OPS)[:]  # gets rid of all useless training attributes in the model graph
MODEL.save(f'{MODEL_PATH}/{MODEL_NAME}')

# %% [markdown]
# ### Convert model to TensorFlow Lite format

# %%
# %run freeze_model.py
# Out:
# W0923 10:41:42.006504 18044 deprecation_wrapper.py:119] From C:\Users\chiso\Google Drive Developer\Humandroid\Workspace\freeze_model.py:18: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# W0923 10:41:42.397197 18044 deprecation.py:323] From C:\Users\chiso\Google Drive Developer\Humandroid\Workspace\freeze_model.py:23: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0923 10:41:42.399144 18044 deprecation.py:323] From C:\Users\chiso\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# Graph successfully frozen!
# File: 'frozen_model.pb' created successfully!

# %%
gf = tf.GraphDef()   
m_file = open('frozen_graph.pb','rb')
gf.ParseFromString(m_file.read())

with open('somefile.txt', 'a') as the_file:
    for n in gf.node:
        the_file.write(n.name+'\n')

file = open('somefile.txt','r')
data = file.readlines()
print "output name = "
print data[len(data)-1]

print "Input name = "
file.seek ( 0 )
print file.readline()

# %%
"""converter = tf.lite.TFLiteConverter.from_frozen_graph('frozen_model.pb')
tflite_model = converter.convert()
open("converted_model.tflite", "wb").write(tflite_model)"""
# Out:
# 'converter = tf.lite.TFLiteConverter.from_frozen_graph(\'frozen_model.pb\')\ntflite_model = converter.convert()\nopen("converted_model.tflite", "wb").write(tflite_model)'

# %% [markdown]
# # RESULTS

# %%
CLASS_INDEX = dict(zip([np.argmax(x) for x in encoded_labels], LABELS.flatten()))
# CLASS_INDEX = dict(sorted(CLASS_INDEX.items()))
LABELS = LABELS.flatten()
IMAGE_IDs = []
CLASS_INDEX
# Out:
# {0: 'Allie Haze',
#  1: 'Ariel X',
#  2: 'Ariella Ferrera',
#  3: 'Mellanie Monroe',
#  4: 'Samantha Ryan',
#  5: 'Tanya Tate'}

# %% [markdown]
# ### Graph Plot of Predicted Classes

# %%
fig = plt.figure()
results = {cls: [] for cls in LABELS}

# iterate over each image in test_sample
# get the model's class prediction of the image
for num, data in enumerate(test_data):
    img_data = data[0]
    img_num = data[1]
    y = fig.add_subplot(4, 4, num + 1)
    orig = img_data
    data = img_data.reshape(IMG_SIZE, IMG_SIZE, 1)
    model_out = MODEL.predict([data])[0]
    index = np.argmax(model_out)

    # generate output dictionary
    results = {LABELS[i]: results.get(LABELS[i]) + [model_out[i]] for i in range(NUM_CLASSES)}
    IMAGE_IDs.append(img_num)
    
    # cross-reference the predicted class-index to its class-label (for each test image)
    class_label = CLASS_INDEX.get(index, 'Invalid class!')
    # print(f"Image ID: {img_num} | \tModel Output: {model_out}  \t | Prediction: {index}")

    y.imshow(orig, cmap='gray')
    plt.title(f'{img_num}: {class_label}')
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
plt.show()
plt.savefig('Class Results')

# %% [markdown]
# ### Tabulated Prediction Probabilities

# %%
# Creates a HeatMap using the seaborn library
cm = sns.light_palette("purple", as_cmap=True)
df = pd.DataFrame.from_dict(results, orient='index', columns=['Image '+ str(i) for i in IMAGE_IDs])
df.style.\
    format("{:.2%}").\
    set_caption('Confidence Values')\
    .background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col0 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col1 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col2 {
#             background-color:  #fcdffc;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col4 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col5 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col6 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col7 {
#             background-color:  #fee4fe;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col8 {
#             background-color:  #fbdefb;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col9 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col10 {
#             background-color:  #f5d3f5;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col11 {
#             background-color:  #f9daf9;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col12 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col13 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col14 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row0_col15 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col0 {
#             background-color:  #f3cff3;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col1 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col2 {
#             background-color:  #f9daf9;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col4 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col5 {
#             background-color:  #fcdffc;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col6 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col7 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col8 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col9 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col10 {
#             background-color:  #fce0fc;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col11 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col12 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col13 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col14 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row1_col15 {
#             background-color:  #fde2fd;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col0 {
#             background-color:  #a94ba9;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col1 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col2 {
#             background-color:  #fce0fc;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col3 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col4 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col5 {
#             background-color:  #d89ed8;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col6 {
#             background-color:  #fee4fe;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col7 {
#             background-color:  #fee3fe;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col8 {
#             background-color:  #fbddfb;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col9 {
#             background-color:  #fee4fe;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col10 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col11 {
#             background-color:  #fbddfb;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col12 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col13 {
#             background-color:  #fce0fc;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col14 {
#             background-color:  #fadcfa;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row2_col15 {
#             background-color:  #fde1fd;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col0 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col1 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col2 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col4 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col5 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col6 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col7 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col8 {
#             background-color:  #f9dbf9;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col9 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col10 {
#             background-color:  #fde2fd;
#             color:  #000000;
#         }    #T_5a352eb6_dde6_11e9_a944_cc4bc1d1a3e9row3_col11 {
#             background-color:  #ffe5ff;

# %%
"""
Re-structures the results dictionary so that each class_label points to another dictionary {k, v}
where k = the Image_Id number and v = the confidence value
"""

def gen_results(results):
    my_dict = {}
    for cls in LABELS:
        probs = iter(results[cls])
        my_dict.update({cls: {}})
        for k in IMAGE_IDs:
            my_dict[cls][int(k)] = next(probs)

    return my_dict

# %%
def get_top3(results, ID=1):
    results = gen_results(results)
    probs = np.array([(results[k][ID]) for k in results])
    # print(f'Reverse: {(-probs).argsort()} - {sorted(probs, reverse=True)}')
    indices = (-probs).argsort()[:3] # sorts probabilities (largest - smallest) + returns their corresponding array indices
    top_3 = [CLASS_INDEX.get(index) for index in indices]
    return top_3

# %%
Image_ID = 5
TOP_3 = get_top3(results, Image_ID)
TOP_3
# Out:
# ['Ariel X', 'Allie Haze', 'Ariella Ferrera']

# %% [markdown]
# # TENSORBOARD

# %%
# !tensorboard --logdir=foo:"C:\Users\chiso\Google Drive Developer\Humandroid\Workspace\log"
